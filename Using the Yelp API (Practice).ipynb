# %%
import json
with open('/Users/ashik/.secret/yelp_api.json') as f:
    login = json.load(f)
    
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
from yelpapi import YelpAPI
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
search_results = yelp_api.search_query(location = 'San Jose,CA',
                                      term = 'Pizza')


print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 2200

# %%
import pandas as pd
business = pd.DataFrame(search_results['businesses'])
business
# Out:
#                         id                              alias  \
# 0   QNzqZtNb_I1mcHAviE5zeQ            bibos-ny-pizza-san-jose
# 1   7NOpkoAUAGqMKEZgSu1QmA       a-slice-of-new-york-san-jose
# 2   7HBtj81aBo2DEZFTPaaeqg     slice-of-homage-pizza-san-jose
# 3   zVCIEtCsInWBZIs1vF73wg           square-pie-guys-campbell
# 4   vZ41QYMBQvtHgpAfw1IToQ              pizza-antica-san-jose
# 5   A9rkSpmfro-rtO1mH2174g                cali-pizza-san-jose
# 6   pxFijJNBpDkkNSfJK9NLvg  the-pizza-press-san-jose-san-jose
# 7   bCMEyV3vxi0n1kgX5yD80w           blue-line-pizza-campbell
# 8   HDQNWPL2gF4_jayyG--D6A               jtown-pizza-san-jose
# 9   95tlD3LE0M_vLLwjcmoNjA         high-five-pizza-san-jose-2
# 10  3Ab38iMfrVHSGJFTfM7B6A             the-pizza-box-san-jose
# 11  LsvST35GTtypxKXleL0g7g             ciceros-pizza-san-jose
# 12  OjLI_vq65QCFkJ0ysmkzyA            got2go-pizza-san-jose-2
# 13  iDPJF-epQNoxGe2eC4NY_A      jakes-of-willow-glen-san-jose
# ...

# %%
search_results = yelp_api.search_query(location = 'San Jose,CA',
                                      term = 'Pizza',
                                      offset = 20)


business_20 = pd.DataFrame(search_results['businesses'])
business_20
# Out:
#                         id                                    alias  \
# 0   T0Ujp4lL_apRxR2dopVVKw                       mas-pizza-san-jose
# 1   K7ADNJhTS4OZ5xzX2PMEMw                pizza-california-san-jose
# 2   OHXPx6P6DKspv2qVjJN9Iw           tony-di-maggios-pizza-san-jose
# 3   QKUIvZHMCchqBMN1tdo7bQ                  bossmans-pizza-san-jose
# 4   vDmGBY09fUawZKVyh5ozLQ          sliver-pizzeria-fremont-fremont
# 5   MEfOIAnLS4dYCdoCuuAhcw            king-kong-ny-pizza-san-jose-4
# 6   Puomhb07PTVBn8jrZ9p0pg                        mr-pizza-san-jose
# 7   5hoAAdJ2XUVwFnmX49nyqw      colosseum-new-york-pizza-milpitas-5
# 8   uQkrc4wtc29zMIfuhnEFpw                parktown-pizza-san-jose-2
# 9   OTfQNVRGRcTeZPlxd2F6bA                  pomodoro-pizza-san-jose
# 10  OEcqMG6YRjOZZ0ikjMcP6A  tony-and-albas-pizza-and-pasta-san-jose
# 11  9X1lX41OJkYwMAn89Ossjw                    got2go-pizza-san-jose
# 12  hHT8GoGHQCLg-5PFlrj7oA                     amato-pizza-san-jose
# ...

# %%
businesses = pd.concat([business, business_20], ignore_index=True)
businesses
# Out:
#                         id                                    alias  \
# 0   QNzqZtNb_I1mcHAviE5zeQ                  bibos-ny-pizza-san-jose
# 1   7NOpkoAUAGqMKEZgSu1QmA             a-slice-of-new-york-san-jose
# 2   7HBtj81aBo2DEZFTPaaeqg           slice-of-homage-pizza-san-jose
# 3   zVCIEtCsInWBZIs1vF73wg                 square-pie-guys-campbell
# 4   vZ41QYMBQvtHgpAfw1IToQ                    pizza-antica-san-jose
# 5   A9rkSpmfro-rtO1mH2174g                      cali-pizza-san-jose
# 6   pxFijJNBpDkkNSfJK9NLvg        the-pizza-press-san-jose-san-jose
# 7   bCMEyV3vxi0n1kgX5yD80w                 blue-line-pizza-campbell
# 8   HDQNWPL2gF4_jayyG--D6A                     jtown-pizza-san-jose
# 9   95tlD3LE0M_vLLwjcmoNjA               high-five-pizza-san-jose-2
# 10  3Ab38iMfrVHSGJFTfM7B6A                   the-pizza-box-san-jose
# 11  LsvST35GTtypxKXleL0g7g                   ciceros-pizza-san-jose
# 12  OjLI_vq65QCFkJ0ysmkzyA                  got2go-pizza-san-jose-2
# ...

# %%
businesses.to_json(orient='records')
# Out:
# '[{"id":"QNzqZtNb_I1mcHAviE5zeQ","alias":"bibos-ny-pizza-san-jose","name":"Bibo\'s Ny Pizza","image_url":"https:\\/\\/s3-media3.fl.yelpcdn.com\\/bphoto\\/slNv72CZB3njkm6xSe0_yA\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/bibos-ny-pizza-san-jose?adjust_creative=S_awMxgKWJl4zVnTzUKhxQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=S_awMxgKWJl4zVnTzUKhxQ","review_count":1388,"categories":[{"alias":"pizza","title":"Pizza"}],"rating":4.5,"coordinates":{"latitude":37.306477956,"longitude":-121.8916095891},"transactions":["pickup"],"price":"$$","location":{"address1":"1431 Bird Ave","address2":null,"address3":"","city":"San Jose","zip_code":"95125","country":"US","state":"CA","display_address":["1431 Bird Ave","San Jose, CA 95125"]},"phone":"+14082179084","display_phone":"(408) 217-9084","distance":1253.6474035102},{"id":"7NOpkoAUAGqMKEZgSu1QmA","alias":"a-slice-of-new-york-san-jose","name":"A Slice of New York","image_url":"https:\\/\\/s3-media
# ...
